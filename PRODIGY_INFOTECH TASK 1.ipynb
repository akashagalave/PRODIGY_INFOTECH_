# %% [markdown]
# # PRODIGY INFOTECH

# %% [markdown]
# # BY AKASH AGALAVE

# %% [markdown]
# PROBLEM STATEMENT

# %% [markdown]
# # TASK 1 : CREATE A BAR CHART OR HISTOGRAM TO VISUALIZE THE DISTRIBUTION OF A CATEGORICAL OR CONTINUOUS VARIABLE, SUCH AS THE DISTRIBUTION OF AGES OR GENDERS IN A POPULATION.

# %%
# importing all library
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("World Development Indiacator(2001-2022).csv")
df
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         2001         2002         2003         2004  \
# 0      SP.POP.TOTL      90691.0      91781.0      92701.0      93540.0
# ...

# %%
df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           2001         2002         2003         2004         2005  \
# 0      90691.0      91781.0      92701.0      93540.0      94483.0
# 1  412001885.0  422741118.0  433807484.0  445281555.0  457153837.0
# 2   19688632.0   21000256.0   22645130.0   23553551.0   24411191.0
# 3  277160097.0  284952322.0  292977949.0  301265247.0  309824829.0
# 4   16941587.0   17516139.0   18124342.0   18771125.0   19450959.0
#
#           2006  ...         2013         2014         2015         2016  \
# ...

# %%
df.tail()
# Out:
#      Country Name Country Code     Indicator Name Indicator Code        2001  \
# 261        Kosovo          XKX  Population, total    SP.POP.TOTL   1701154.0
# 262   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL  19143457.0
# 263  South Africa          ZAF  Population, total    SP.POP.TOTL  47229714.0
# 264        Zambia          ZMB  Population, total    SP.POP.TOTL  10191964.0
# 265      Zimbabwe          ZWE  Population, total    SP.POP.TOTL  11910978.0
#
#            2002        2003        2004        2005        2006  ...  \
# 261   1702310.0   1703466.0   1704622.0   1705780.0   1719536.0  ...
# 262  19660653.0  20188799.0  20733406.0  21320671.0  21966298.0  ...
# 263  47661514.0  48104048.0  48556071.0  49017147.0  49491756.0  ...
# 264  10508294.0  10837973.0  11188040.0  11564870.0  11971567.0  ...
# 265  11984644.0  12075828.0  12160881.0  12224753.0  12330490.0  ...
#
#            2013        2014        2015        2016        2017        2018  \
# ...

# %%
df.shape
# Out:
# (266, 26)

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019', '2020', '2021', '2022'],
#       dtype='object')

# %%
df.describe()
# Out:
#                2001          2002          2003          2004          2005  \
# count  2.650000e+02  2.650000e+02  2.650000e+02  2.650000e+02  2.650000e+02
# mean   2.492924e+08  2.527984e+08  2.563013e+08  2.598104e+08  2.633363e+08
# std    7.901099e+08  8.006981e+08  8.111965e+08  8.216943e+08  8.321848e+08
# min    9.621000e+03  9.609000e+03  9.668000e+03  9.791000e+03  9.912000e+03
# 25%    1.306590e+06  1.341696e+06  1.353548e+06  1.361172e+06  1.369075e+06
# 50%    8.223941e+06  8.372306e+06  8.567992e+06  8.791853e+06  9.026299e+06
# 75%    5.010666e+07  5.166207e+07  5.320564e+07  5.481561e+07  5.655025e+07
# max    6.226348e+09  6.308141e+09  6.389462e+09  6.470924e+09  6.552700e+09
#
#                2006          2007          2008          2009          2010  \
# count  2.650000e+02  2.650000e+02  2.650000e+02  2.650000e+02  2.650000e+02
# mean   2.668780e+08  2.704273e+08  2.740244e+08  2.776644e+08  2.813373e+08
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   2001            265 non-null    float64
#  5   2002            265 non-null    float64
#  6   2003            265 non-null    float64
#  7   2004            265 non-null    float64
#  8   2005            265 non-null    float64
#  9   2006            265 non-null    float64
#  10  2007            265 non-null    float64
#  11  2008            265 non-null    float64
#  12  2009            265 non-null    float64
#  13  2010            265 non-null    float64
#  14  2011            265 non-null    float64
#  15  2012            265 non-null    float64
#  16  2013            265 non-null    float64
# ...

# %%
df.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 2001              float64
# 2002              float64
# 2003              float64
# 2004              float64
# 2005              float64
# 2006              float64
# 2007              float64
# 2008              float64
# 2009              float64
# 2010              float64
# 2011              float64
# 2012              float64
# 2013              float64
# 2014              float64
# 2015              float64
# 2016              float64
# 2017              float64
# 2018              float64
# 2019              float64
# 2020              float64
# 2021              float64
# 2022              float64
# dtype: object

# %%
df.isna().sum().any()
# Out:
# True

# %%
df['Country Name'].unique()
# Out:
# array(['Aruba', 'Africa Eastern and Southern', 'Afghanistan',
#        'Africa Western and Central', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates', 'Argentina', 'Armenia',
#        'American Samoa', 'Antigua and Barbuda', 'Australia', 'Austria',
#        'Azerbaijan', 'Burundi', 'Belgium', 'Benin', 'Burkina Faso',
#        'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas, The',
#        'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bermuda',
#        'Bolivia', 'Brazil', 'Barbados', 'Brunei Darussalam', 'Bhutan',
#        'Botswana', 'Central African Republic', 'Canada',
#        'Central Europe and the Baltics', 'Switzerland', 'Channel Islands',
#        'Chile', 'China', "Cote d'Ivoire", 'Cameroon', 'Congo, Dem. Rep.',
#        'Congo, Rep.', 'Colombia', 'Comoros', 'Cabo Verde', 'Costa Rica',
#        'Caribbean small states', 'Cuba', 'Curacao', 'Cayman Islands',
#        'Cyprus', 'Czechia', 'Germany', 'Djibouti', 'Dominica', 'Denmark',
# ...

# %%
df['Country Code'].unique()
# Out:
# array(['ABW', 'AFE', 'AFG', 'AFW', 'AGO', 'ALB', 'AND', 'ARB', 'ARE',
#        'ARG', 'ARM', 'ASM', 'ATG', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL',
#        'BEN', 'BFA', 'BGD', 'BGR', 'BHR', 'BHS', 'BIH', 'BLR', 'BLZ',
#        'BMU', 'BOL', 'BRA', 'BRB', 'BRN', 'BTN', 'BWA', 'CAF', 'CAN',
#        'CEB', 'CHE', 'CHI', 'CHL', 'CHN', 'CIV', 'CMR', 'COD', 'COG',
#        'COL', 'COM', 'CPV', 'CRI', 'CSS', 'CUB', 'CUW', 'CYM', 'CYP',
#        'CZE', 'DEU', 'DJI', 'DMA', 'DNK', 'DOM', 'DZA', 'EAP', 'EAR',
#        'EAS', 'ECA', 'ECS', 'ECU', 'EGY', 'EMU', 'ERI', 'ESP', 'EST',
#        'ETH', 'EUU', 'FCS', 'FIN', 'FJI', 'FRA', 'FRO', 'FSM', 'GAB',
#        'GBR', 'GEO', 'GHA', 'GIB', 'GIN', 'GMB', 'GNB', 'GNQ', 'GRC',
#        'GRD', 'GRL', 'GTM', 'GUM', 'GUY', 'HIC', 'HKG', 'HND', 'HPC',
#        'HRV', 'HTI', 'HUN', 'IBD', 'IBT', 'IDA', 'IDB', 'IDN', 'IDX',
#        'IMN', 'IND', 'INX', 'IRL', 'IRN', 'IRQ', 'ISL', 'ISR', 'ITA',
# ...

# %%
df['Indicator Name'].unique()
# Out:
# array(['Population, total'], dtype=object)

# %%
df['Indicator Code'].unique()
# Out:
# array(['SP.POP.TOTL'], dtype=object)

# %%
# filter data for total population
total_population_df=df[df['Indicator Code']=='SP.POP.TOTL']
total_population_df
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         2001         2002         2003         2004  \
# 0      SP.POP.TOTL      90691.0      91781.0      92701.0      93540.0
# ...

# %%
# sort data based on total population for 2022
total_population_sort = total_population_df.sort_values(by='2022',ascending=False)
total_population_sort
# Out:
#                Country Name Country Code     Indicator Name Indicator Code  \
# 259                   World          WLD  Population, total    SP.POP.TOTL
# 103        IDA & IBRD total          IBT  Population, total    SP.POP.TOTL
# 140     Low & middle income          LMY  Population, total    SP.POP.TOTL
# 156           Middle income          MIC  Population, total    SP.POP.TOTL
# 102               IBRD only          IBD  Population, total    SP.POP.TOTL
# ..                      ...          ...                ...            ...
# 255  British Virgin Islands          VGB  Population, total    SP.POP.TOTL
# 188                   Palau          PLW  Population, total    SP.POP.TOTL
# 179                   Nauru          NRU  Population, total    SP.POP.TOTL
# 245                  Tuvalu          TUV  Population, total    SP.POP.TOTL
# 110          Not classified          INX  Population, total    SP.POP.TOTL
#
# ...

# %% [markdown]
# ## TOP 10 COUNTRIES WITH THE HIGHEST POPULATION FOR 2022

# %%
# get top 10 countries with the highest population for 2022
top_ten_countries = total_population_sort.head(10)
print("Top Ten Counteies Of Total Population:-")
print(top_ten_countries)
# Out:
# Top Ten Counteies Of Total Population:-
#                    Country Name Country Code     Indicator Name  \
# 259                       World          WLD  Population, total
# 103            IDA & IBRD total          IBT  Population, total
# 140         Low & middle income          LMY  Population, total
# 156               Middle income          MIC  Population, total
# 102                   IBRD only          IBD  Population, total
# 62   Early-demographic dividend          EAR  Population, total
# 139         Lower middle income          LMC  Population, total
# 249         Upper middle income          UMC  Population, total
# 63          East Asia & Pacific          EAS  Population, total
# 142   Late-demographic dividend          LTE  Population, total
#
#     Indicator Code          2001          2002          2003          2004  \
# 259    SP.POP.TOTL  6.226348e+09  6.308141e+09  6.389462e+09  6.470924e+09
# ...

# %% [markdown]
# DATA VISUALIZATION

# %%
# Data visualization
def add_value_labels(ax,spacing=10):
    for rect in ax.patches:
        x=rect.get_x()+rect.get_width()/2
        y=rect.get_height()-3
        
        va='bottom' if y>=0 else 'top'
        label= '()'.format(y) 
        y_shift = spacing * (1 if y >= 0 else -1)
        ax.annotate(label,(x,y),xytext=(0,y_shift),textcoords="offset points",ha='center',va=va)

# %% [markdown]
# ## TOP 10 COUNTRIES OF TOTAL POPULATION IN YEAR 2022 TO 2001

# %%
# creat a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='2022',y="Country Name",data=top_ten_countries,palette="coolwarm")
plt.title("Top Ten countries Of Total Population (2022)")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='2001',y="Country Name",data=top_ten_countries,palette="coolwarm")
plt.title("Top Ten countries Of Total Population in 2000")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.tight_layout()

# %% [markdown]
# ## BOTTOM 10 COUNTRIES WITH THE HIGHEST POPULATION

# %%
# sort data based on total population for 2022
total_population_sort_bt = total_population_df.sort_values(by='2022',ascending=True)
total_population_sort_bt
# Out:
#                  Country Name Country Code     Indicator Name Indicator Code  \
# 245                    Tuvalu          TUV  Population, total    SP.POP.TOTL
# 179                     Nauru          NRU  Population, total    SP.POP.TOTL
# 188                     Palau          PLW  Population, total    SP.POP.TOTL
# 255    British Virgin Islands          VGB  Population, total    SP.POP.TOTL
# 147  St. Martin (French part)          MAF  Population, total    SP.POP.TOTL
# ..                        ...          ...                ...            ...
# 156             Middle income          MIC  Population, total    SP.POP.TOTL
# 140       Low & middle income          LMY  Population, total    SP.POP.TOTL
# 103          IDA & IBRD total          IBT  Population, total    SP.POP.TOTL
# 259                     World          WLD  Population, total    SP.POP.TOTL
# 110            Not classified          INX  Population, total    SP.POP.TOTL
#
# ...

# %%
top_ten_bt_countries = total_population_sort_bt.head(10)
print("Top Ten Bottom Counteies Of Total Population:-")
print(top_ten_bt_countries)
# Out:
# Top Ten Bottom Counteies Of Total Population:-
#                  Country Name Country Code     Indicator Name Indicator Code  \
# 245                    Tuvalu          TUV  Population, total    SP.POP.TOTL
# 179                     Nauru          NRU  Population, total    SP.POP.TOTL
# 188                     Palau          PLW  Population, total    SP.POP.TOTL
# 255    British Virgin Islands          VGB  Population, total    SP.POP.TOTL
# 147  St. Martin (French part)          MAF  Population, total    SP.POP.TOTL
# 84                  Gibraltar          GIB  Population, total    SP.POP.TOTL
# 212                San Marino          SMR  Population, total    SP.POP.TOTL
# 149                    Monaco          MCO  Population, total    SP.POP.TOTL
# 137             Liechtenstein          LIE  Population, total    SP.POP.TOTL
# 155          Marshall Islands          MHL  Population, total    SP.POP.TOTL
#
#         2001     2002     2003     2004     2005     2006  ...     2013  \
# ...

# %% [markdown]
# ## BOTTOM 10 COUNTRIES OF TOTAL POPULATION IN A YEAR 2022 TO 2001

# %%
# creat a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='2022',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
plt.title("Top Ten Bottom countries Of Total Population (2022)")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='2001',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
plt.title("Top Ten Bottom countries Of Total Population in 2000")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.tight_layout()

# %% [markdown]
# ### EXTRACTED TOP 10 COUNTRIES WITH HIGHEST MALE POPULATION

# %%
df.sample(10)
# Out:
#                Country Name Country Code     Indicator Name Indicator Code  \
# 260                   Samoa          WSM  Population, total    SP.POP.TOTL
# 19             Burkina Faso          BFA  Population, total    SP.POP.TOTL
# 49   Caribbean small states          CSS  Population, total    SP.POP.TOTL
# 163                Mongolia          MNG  Population, total    SP.POP.TOTL
# 211             El Salvador          SLV  Population, total    SP.POP.TOTL
# 178                   Nepal          NPL  Population, total    SP.POP.TOTL
# 58                  Denmark          DNK  Population, total    SP.POP.TOTL
# 180             New Zealand          NZL  Population, total    SP.POP.TOTL
# 205            Saudi Arabia          SAU  Population, total    SP.POP.TOTL
# 221         Slovak Republic          SVK  Population, total    SP.POP.TOTL
#
#            2001        2002        2003        2004        2005        2006  \
# ...

# %%
# filter data for total male population
total_population_male=df[df['Indicator Code']=='SP.POP.TOTL.MA.IN']
total_population_male
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Indicator Name, Indicator Code, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Index: []
#
# [0 rows x 26 columns]

# %%
# sort data based on total population for 2022
total_population_sort_ma = total_population_male.sort_values(by='2022',ascending=False)
total_population_sort_ma
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Indicator Name, Indicator Code, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Index: []
#
# [0 rows x 26 columns]

# %%
# get top 10 countries with the highest population for 2022
top_ten_male_countries = total_population_sort_ma.head(10)
print("Top Ten male Counteies Of Total Population:-")
print(top_ten_male_countries)
# Out:
# Top Ten male Counteies Of Total Population:-
# Empty DataFrame
# Columns: [Country Name, Country Code, Indicator Name, Indicator Code, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# # THANKYOU
