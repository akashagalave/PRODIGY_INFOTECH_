# %% [markdown]
# #                         IRIS DATASET

# %% [markdown]
# # BY AKASH AGALAVE

# %%
# importing all library
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
# Loading the Dataset
df = pd.read_csv('iris.csv')
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df.tail()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %%
# Showing inforamation about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# number of row and columns
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
# Checking for data types
df.dtypes
# Out:
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %%
# Again checking the number of mission value in each columns
df.isna().sum()
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %%
# Finding the number of variety
df["variety"].value_counts()
# Out:
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: variety, dtype: int64

# %%
# Data analysic 
# Getting some statistical measures about the data
df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# Statistical Analysis about categorical columns
df.describe(include='O')
# Out:
#        variety
# count      150
# unique       3
# top     Setosa
# freq        50

# %% [markdown]
# ## DATA VISUALIZATION

# %%
df.plot(x="sepal.length", y="sepal.width", kind="scatter")
# Out:
# <Axes: xlabel='sepal.length', ylabel='sepal.width'>

# %%
# Plotting Jointplot for Dataset
sns.jointplot(x='sepal.length', y='sepal.width', data=df, size=5)

# %%
# plotting Barplot for Dataset 
sns.barplot(x="variety", y="sepal.length", data = df)
# Out:
# <Axes: xlabel='variety', ylabel='sepal.length'>

# %%
sns.FacetGrid(df, hue="variety").map(plt.scatter,"sepal.length","sepal.width").add_legend()

# %%
sns.violinplot(x="variety", y="petal.length",data=df,size=6)
# Out:
# <Axes: xlabel='variety', ylabel='petal.length'>

# %%
# Plotting Histplot for Dataset
df.hist(figsize=(10,10),color = '#5C8374')
plt.show()

# %%
cat_cols = df.select_dtypes(include='object').columns
cat_cols
# Out:
# Index(['variety'], dtype='object')

# %%
#Iris Distribution of Sepal.length Wise
sns.histplot(x=df['sepal.length'],kde=True,color='green')
plt.title('Iris')
plt.show()

# %%
#Iris Distribution of Sepal.Width Wise
sns.histplot(x=df['sepal.width'],kde=True,color='blue')
plt.title('Iris')
plt.show()

# %%
#Iris Distribution of Petal.length Wise
sns.histplot(x=df['petal.length'],kde=True,color='red')
plt.title('Iris')
plt.show()

# %%
#Iris Distribution of Petal.Width Wise
sns.histplot(x=df['petal.width'],kde=True,color='teal')
plt.title('Iris')
plt.show()

# %%
# Showing Correlation Plot
heatmap = sns.heatmap(df.corr() ,annot = True)  
heatmap.set (title = "Iris\n")  
plt.show()

# %%
# Showing Correlation map
correlation = df.corr()  
correlation.style.background_gradient(cmap = 'flare')
# Out:
# <style type="text/css">
# #T_9298e_row0_col0, #T_9298e_row1_col1, #T_9298e_row2_col2, #T_9298e_row3_col3 {
#   background-color: #4b2362;
#   color: #f1f1f1;
# }
# #T_9298e_row0_col1 {
#   background-color: #e77a62;
#   color: #f1f1f1;
# }
# #T_9298e_row0_col2 {
#   background-color: #5f2969;
#   color: #f1f1f1;
# }
# #T_9298e_row0_col3 {
#   background-color: #6a2b6c;
#   color: #f1f1f1;
# }
# #T_9298e_row1_col0, #T_9298e_row1_col2, #T_9298e_row1_col3, #T_9298e_row2_col1 {
#   background-color: #edb081;
#   color: #000000;
# }
# #T_9298e_row2_col0 {
#   background-color: #652a6b;
#   color: #f1f1f1;
# }
# #T_9298e_row2_col3, #T_9298e_row3_col2 {
#   background-color: #502564;
#   color: #f1f1f1;
# }
# #T_9298e_row3_col0 {
#   background-color: #712c6e;
#   color: #f1f1f1;
# }
# #T_9298e_row3_col1 {
#   background-color: #eca57a;
#   color: #000000;
# }
# </style>
# <table id="T_9298e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
# Data visualization
def add_value_labels(ax,spacing=10):
    for rect in ax.patches:
        x=rect.get_x()+rect.get_width()/2
        y=rect.get_height()-3
        
        va='bottom' if y>=0 else 'top'
        label= '()'.format(y) 
        y_shift = spacing * (1 if y >= 0 else -1)
        ax.annotate(label,(x,y),xytext=(0,y_shift),textcoords="offset points",ha='center',va=va)

# %%
# create a bar plot
plt.figure(figsize=(20,20))
plt.rcParams['axes.facecolor']=="blue"

plt.subplot(2,2,1)
plot=sns.barplot(x='sepal.length',y="variety",data=df,palette="viridis")
plt.title("IRIS")
plt.xlabel("SEPAL.LENGTH")
plt.ylabel("VARIETY")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='sepal.width',y="variety",data=df,palette="viridis")
plt.title("IRIS")
plt.xlabel("SEPAL.WIDTH")
plt.ylabel("VARIETY")
add_value_labels(plot)

plt.subplot(2,2,3)
plot=sns.barplot(x='petal.length',y="variety",data=df,palette="viridis")
plt.title("IRIS")
plt.xlabel("PETAL.LENGTH")
plt.ylabel("VARIETY")
add_value_labels(plot)

plt.subplot(2,2,4)
plot=sns.barplot(x='petal.width',y="variety",data=df,palette="viridis")
plt.title("IRIS")
plt.xlabel("PETAL.WIDTH")
plt.ylabel("VARIETY")
add_value_labels(plot)


plt.tight_layout()
